# %%
import open3d as o3d
from pathlib import Path
import numpy as np

# %%
sparse_0_path = Path('/home/david/projects/embodied_gaussians/datasets/real/single1_aruco/modelling/static/sparse_5/0')

# Load the point cloud
pts3d = np.load(sparse_0_path / 'points3D_all.npy')
col = np.load(sparse_0_path / 'pointsColor_all.npy')

# %%
pts3d.reshape(-1, 3)
# Out:
# array([[ 0.0048306 ,  0.77416754, -1.2068808 ],
#        [ 0.0356724 ,  0.7191094 , -1.1728742 ],
#        [ 0.03143066,  0.7264992 , -1.1754808 ],
#        ...,
#        [ 0.47325635,  0.38355684, -0.8146306 ],
#        [ 0.470203  ,  0.3811614 , -0.8161327 ],
#        [ 0.45830148,  0.3739954 , -0.822387  ]],
#       shape=(737280, 3), dtype=float32)

# %%
# Create an Open3D point cloud
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(pts3d.reshape(-1, 3))
pcd.colors = o3d.utility.Vector3dVector(col.reshape(-1, 3))

# Visualize the point cloud
o3d.visualization.draw_geometries([pcd])
